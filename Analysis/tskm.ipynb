# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
plt.style.use('ggplot')
plt.rcParams['font.family'] = 'Malgun Gothic' 
#plt.rc('font', family='Malgun Gothic')
plt.rcParams['font.serif'] = 'Ubuntu' 
plt.rcParams['font.monospace'] = 'Ubuntu Mono' 
plt.rcParams['font.size'] = 14 
plt.rcParams['axes.labelsize'] = 12 
plt.rcParams['axes.labelweight'] = 'bold' 
plt.rcParams['axes.titlesize'] = 12 
plt.rcParams['xtick.labelsize'] = 12 
plt.rcParams['ytick.labelsize'] = 12 
plt.rcParams['legend.fontsize'] = 12 
plt.rcParams['figure.titlesize'] = 12 
plt.rcParams['image.cmap'] = 'jet' 
plt.rcParams['image.interpolation'] = 'none' 
plt.rcParams['figure.figsize'] = (20, 15) 
plt.rcParams['axes.grid']=True
plt.rcParams['lines.linewidth'] = 2 
plt.rcParams['lines.markersize'] = 8
colors = ['xkcd:pale orange', 'xkcd:sea blue', 'xkcd:pale red', 'xkcd:sage green', 'xkcd:terra cotta', 'xkcd:dull purple', 'xkcd:teal', 'xkcd: goldenrod', 'xkcd:cadet blue',
'xkcd:scarlet']

# %%
df_ = pd.read_csv('cluster_1.csv')
df_.head()
# Out:
#    Unnamed: 0          날짜   강원도 강릉시  강원도 고성군  강원도 동해시  강원도 삼척시   강원도 속초시  \
# 0           0  2020-01-01  197344.0  57981.0  55454.0  49980.0  122514.0
# 1           1  2020-01-02   87395.0  25466.0  24920.0  24335.5   59955.0
# 2           2  2020-01-03   92099.0  25329.5  28948.5  25868.5   62699.0
# 3           3  2020-01-04  133178.5  37733.5  38171.0  33267.5   92459.5
# 4           4  2020-01-05  111303.5  33246.5  32791.5  31566.5   76877.5
#
#    강원도 양구군   강원도 양양군  강원도 영월군  ...  충청북도 옥천군  충청북도 음성군  충청북도 제천시  충청북도 증평군  \
# 0   5862.5  121121.0  15620.5  ...   30114.0   31052.0   34384.0   13863.5
# 1   4795.0   31328.5  10118.5  ...   18221.0   29561.0   23145.5   11578.0
# 2   4830.0   31125.5  10983.0  ...   20884.5   33568.5   27055.0   13398.0
# 3   5680.5   54148.5  17965.5  ...   28812.0   36715.0   38836.0   15008.0
# 4   5621.0   47145.0  17104.5  ...   29683.5   31223.5   33883.5   13846.0
#
#    충청북도 진천군  충청북도 청주시 상당구  충청북도 청주시 서원구  충청북도 청주시 청원구  충청북도 청주시 흥덕구  충청북도 충주시
# 0   22879.5       80150.0       82050.5       61400.5       79425.5   55475.0
# 1   20384.0       60028.5       65030.0       52535.0       70486.5   37124.5
# 2   22452.5       67788.0       74763.5       60886.0       81385.5   42959.0
# 3   24892.0       89211.5       92617.0       75614.0       98311.5   60718.0
# 4   25116.0       80279.5       76895.0       62632.5       81567.5   56045.5
#
# [5 rows x 252 columns]

# %%
df = df_.iloc[:, 1:]
df.head()
# Out:
#            날짜   강원도 강릉시  강원도 고성군  강원도 동해시  강원도 삼척시   강원도 속초시  강원도 양구군  \
# 0  2020-01-01  197344.0  57981.0  55454.0  49980.0  122514.0   5862.5
# 1  2020-01-02   87395.0  25466.0  24920.0  24335.5   59955.0   4795.0
# 2  2020-01-03   92099.0  25329.5  28948.5  25868.5   62699.0   4830.0
# 3  2020-01-04  133178.5  37733.5  38171.0  33267.5   92459.5   5680.5
# 4  2020-01-05  111303.5  33246.5  32791.5  31566.5   76877.5   5621.0
#
#     강원도 양양군  강원도 영월군  강원도 원주시  ...  충청북도 옥천군  충청북도 음성군  충청북도 제천시  충청북도 증평군  \
# 0  121121.0  15620.5  82344.5  ...   30114.0   31052.0   34384.0   13863.5
# 1   31328.5  10118.5  62604.5  ...   18221.0   29561.0   23145.5   11578.0
# 2   31125.5  10983.0  76751.5  ...   20884.5   33568.5   27055.0   13398.0
# 3   54148.5  17965.5  95287.5  ...   28812.0   36715.0   38836.0   15008.0
# 4   47145.0  17104.5  93229.5  ...   29683.5   31223.5   33883.5   13846.0
#
#    충청북도 진천군  충청북도 청주시 상당구  충청북도 청주시 서원구  충청북도 청주시 청원구  충청북도 청주시 흥덕구  충청북도 충주시
# 0   22879.5       80150.0       82050.5       61400.5       79425.5   55475.0
# 1   20384.0       60028.5       65030.0       52535.0       70486.5   37124.5
# 2   22452.5       67788.0       74763.5       60886.0       81385.5   42959.0
# 3   24892.0       89211.5       92617.0       75614.0       98311.5   60718.0
# 4   25116.0       80279.5       76895.0       62632.5       81567.5   56045.5
#
# [5 rows x 251 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Columns: 251 entries, 날짜 to 충청북도 충주시
# dtypes: float64(250), object(1)
# memory usage: 1.4+ MB

# %%
df['날짜'] = df['날짜'].astype('str')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Columns: 251 entries, 날짜 to 충청북도 충주시
# dtypes: float64(250), object(1)
# memory usage: 1.4+ MB

# %%
df['날짜'] =pd.to_datetime(df['날짜'])
df.head()
# Out:
#           날짜   강원도 강릉시  강원도 고성군  강원도 동해시  강원도 삼척시   강원도 속초시  강원도 양구군  \
# 0 2020-01-01  197344.0  57981.0  55454.0  49980.0  122514.0   5862.5
# 1 2020-01-02   87395.0  25466.0  24920.0  24335.5   59955.0   4795.0
# 2 2020-01-03   92099.0  25329.5  28948.5  25868.5   62699.0   4830.0
# 3 2020-01-04  133178.5  37733.5  38171.0  33267.5   92459.5   5680.5
# 4 2020-01-05  111303.5  33246.5  32791.5  31566.5   76877.5   5621.0
#
#     강원도 양양군  강원도 영월군  강원도 원주시  ...  충청북도 옥천군  충청북도 음성군  충청북도 제천시  충청북도 증평군  \
# 0  121121.0  15620.5  82344.5  ...   30114.0   31052.0   34384.0   13863.5
# 1   31328.5  10118.5  62604.5  ...   18221.0   29561.0   23145.5   11578.0
# 2   31125.5  10983.0  76751.5  ...   20884.5   33568.5   27055.0   13398.0
# 3   54148.5  17965.5  95287.5  ...   28812.0   36715.0   38836.0   15008.0
# 4   47145.0  17104.5  93229.5  ...   29683.5   31223.5   33883.5   13846.0
#
#    충청북도 진천군  충청북도 청주시 상당구  충청북도 청주시 서원구  충청북도 청주시 청원구  충청북도 청주시 흥덕구  충청북도 충주시
# 0   22879.5       80150.0       82050.5       61400.5       79425.5   55475.0
# 1   20384.0       60028.5       65030.0       52535.0       70486.5   37124.5
# 2   22452.5       67788.0       74763.5       60886.0       81385.5   42959.0
# 3   24892.0       89211.5       92617.0       75614.0       98311.5   60718.0
# 4   25116.0       80279.5       76895.0       62632.5       81567.5   56045.5
#
# [5 rows x 251 columns]

# %%
cities_list = df.columns.tolist()[0:]
plt.plot(df['날짜'],df[cities_list[1:]])
# Out:
# [<matplotlib.lines.Line2D at 0x298355d8340>,
#  <matplotlib.lines.Line2D at 0x298355d17c0>,
#  <matplotlib.lines.Line2D at 0x2984f7ccd60>,
#  <matplotlib.lines.Line2D at 0x2984f7e73d0>,
#  <matplotlib.lines.Line2D at 0x2984f7e7400>,
#  <matplotlib.lines.Line2D at 0x2984f7e75b0>,
#  <matplotlib.lines.Line2D at 0x2984f7e76d0>,
#  <matplotlib.lines.Line2D at 0x29835621190>,
#  <matplotlib.lines.Line2D at 0x2984f7e77f0>,
#  <matplotlib.lines.Line2D at 0x2984f7e7a00>,
#  <matplotlib.lines.Line2D at 0x2984f7e7b20>,
#  <matplotlib.lines.Line2D at 0x2984f7e7c40>,
#  <matplotlib.lines.Line2D at 0x2984f7e7d60>,
#  <matplotlib.lines.Line2D at 0x2984f7e7e80>,
#  <matplotlib.lines.Line2D at 0x2984f7e7fa0>,
#  <matplotlib.lines.Line2D at 0x2984f7da100>,
#  <matplotlib.lines.Line2D at 0x2984f7da220>,
#  <matplotlib.lines.Line2D at 0x2984f7da340>,
#  <matplotlib.lines.Line2D at 0x2984f7da460>,
#  <matplotlib.lines.Line2D at 0x2984f7da580>,
#  <matplotlib.lines.Line2D at 0x2984f7da6a0>,
#  <matplotlib.lines.Line2D at 0x2984f7da7c0>,
#  <matplotlib.lines.Line2D at 0x2984f7da8e0>,
#  <matplotlib.lines.Line2D at 0x2984f7daa00>,
#  <matplotlib.lines.Line2D at 0x2984f7dab20>,
#  <matplotlib.lines.Line2D at 0x2984f7dac40>,
#  <matplotlib.lines.Line2D at 0x2984f7dad60>,
#  <matplotlib.lines.Line2D at 0x2984f7dae80>,
#  <matplotlib.lines.Line2D at 0x2984f7dafa0>,
#  <matplotlib.lines.Line2D at 0x2984f48ef40>,
#  <matplotlib.lines.Line2D at 0x2984f48ed90>,
#  <matplotlib.lines.Line2D at 0x2984f48ed00>,
#  <matplotlib.lines.Line2D at 0x2984f48ec40>,
#  <matplotlib.lines.Line2D at 0x2984f48ea00>,
#  <matplotlib.lines.Line2D at 0x2984f48e9a0>,
#  <matplotlib.lines.Line2D at 0x2984f48e7f0>,
#  <matplotlib.lines.Line2D at 0x2984f48e760>,
#  <matplotlib.lines.Line2D at 0x2984f48e6a0>,
#  <matplotlib.lines.Line2D at 0x2984f48e460>,
#  <matplotlib.lines.Line2D at 0x2984f48e400>,
#  <matplotlib.lines.Line2D at 0x2984f48e250>,
#  <matplotlib.lines.Line2D at 0x2984f48e1c0>,
#  <matplotlib.lines.Line2D at 0x2984f48e100>,
#  <matplotlib.lines.Line2D at 0x2984f474100>,
#  <matplotlib.lines.Line2D at 0x2984f474220>,
#  <matplotlib.lines.Line2D at 0x2984f474340>,
#  <matplotlib.lines.Line2D at 0x2984f474460>,
#  <matplotlib.lines.Line2D at 0x2984f4745b0>,
#  <matplotlib.lines.Line2D at 0x2984f4746a0>,
#  <matplotlib.lines.Line2D at 0x2984f4747c0>,
#  <matplotlib.lines.Line2D at 0x2984f4748e0>,
#  <matplotlib.lines.Line2D at 0x2984f474a00>,
#  <matplotlib.lines.Line2D at 0x2984f474b20>,
#  <matplotlib.lines.Line2D at 0x2984f474c40>,
#  <matplotlib.lines.Line2D at 0x2984f474d60>,
#  <matplotlib.lines.Line2D at 0x2984f474e80>,
#  <matplotlib.lines.Line2D at 0x2984f474fa0>,
#  <matplotlib.lines.Line2D at 0x2984f470100>,
#  <matplotlib.lines.Line2D at 0x2984f470220>,
#  <matplotlib.lines.Line2D at 0x2984f470340>,
#  <matplotlib.lines.Line2D at 0x2984f470460>,
#  <matplotlib.lines.Line2D at 0x2984f470580>,
#  <matplotlib.lines.Line2D at 0x2984f4706a0>,
#  <matplotlib.lines.Line2D at 0x2984f4707c0>,
#  <matplotlib.lines.Line2D at 0x2984f4708e0>,
#  <matplotlib.lines.Line2D at 0x2984f470a00>,
#  <matplotlib.lines.Line2D at 0x2984f470b20>,
#  <matplotlib.lines.Line2D at 0x2984f470c40>,
#  <matplotlib.lines.Line2D at 0x2984f470d60>,
#  <matplotlib.lines.Line2D at 0x2984f470e80>,
#  <matplotlib.lines.Line2D at 0x2984f470fa0>,
#  <matplotlib.lines.Line2D at 0x2984f4ac100>,
#  <matplotlib.lines.Line2D at 0x2984f4ac220>,
#  <matplotlib.lines.Line2D at 0x2984f4ac340>,
#  <matplotlib.lines.Line2D at 0x2984f4ac460>,
#  <matplotlib.lines.Line2D at 0x2984f4ac580>,
#  <matplotlib.lines.Line2D at 0x2984f4ac6a0>,
#  <matplotlib.lines.Line2D at 0x2984f4ac7c0>,
#  <matplotlib.lines.Line2D at 0x2984f4ac8e0>,
#  <matplotlib.lines.Line2D at 0x2984f4aca00>,
#  <matplotlib.lines.Line2D at 0x2984f4acb20>,
#  <matplotlib.lines.Line2D at 0x2984f4acc40>,
#  <matplotlib.lines.Line2D at 0x2984f4acd60>,
#  <matplotlib.lines.Line2D at 0x2984f4ace80>,
#  <matplotlib.lines.Line2D at 0x2984f4acfa0>,
#  <matplotlib.lines.Line2D at 0x2984f483100>,
#  <matplotlib.lines.Line2D at 0x2984f483220>,
#  <matplotlib.lines.Line2D at 0x2984f483340>,
#  <matplotlib.lines.Line2D at 0x2984f483460>,
#  <matplotlib.lines.Line2D at 0x2984f483580>,
#  <matplotlib.lines.Line2D at 0x2984f4836a0>,
#  <matplotlib.lines.Line2D at 0x2984f4837c0>,
#  <matplotlib.lines.Line2D at 0x2984f4838e0>,
#  <matplotlib.lines.Line2D at 0x2984f483a00>,
#  <matplotlib.lines.Line2D at 0x2984f483b20>,
#  <matplotlib.lines.Line2D at 0x2984f483c40>,
#  <matplotlib.lines.Line2D at 0x2984f483d60>,
#  <matplotlib.lines.Line2D at 0x2984f483e80>,
#  <matplotlib.lines.Line2D at 0x2984f483fa0>,
#  <matplotlib.lines.Line2D at 0x2984f492100>,
#  <matplotlib.lines.Line2D at 0x2984f492220>,
#  <matplotlib.lines.Line2D at 0x2984f492340>,
#  <matplotlib.lines.Line2D at 0x2984f492460>,
#  <matplotlib.lines.Line2D at 0x2984f492580>,
#  <matplotlib.lines.Line2D at 0x2984f4926a0>,
#  <matplotlib.lines.Line2D at 0x2984f4927c0>,
#  <matplotlib.lines.Line2D at 0x2984f4928e0>,
#  <matplotlib.lines.Line2D at 0x2984f492a00>,
#  <matplotlib.lines.Line2D at 0x2984f492b20>,
#  <matplotlib.lines.Line2D at 0x2984f492c40>,
#  <matplotlib.lines.Line2D at 0x2984f492d60>,
#  <matplotlib.lines.Line2D at 0x2984f492e80>,
#  <matplotlib.lines.Line2D at 0x2984f492fa0>,
#  <matplotlib.lines.Line2D at 0x2984f43e100>,
#  <matplotlib.lines.Line2D at 0x2984f43e220>,
#  <matplotlib.lines.Line2D at 0x2984f43e340>,
#  <matplotlib.lines.Line2D at 0x2984f43e460>,
#  <matplotlib.lines.Line2D at 0x2984f43e580>,
#  <matplotlib.lines.Line2D at 0x2984f43e6a0>,
#  <matplotlib.lines.Line2D at 0x2984f43e7c0>,
#  <matplotlib.lines.Line2D at 0x2984f43e8e0>,
#  <matplotlib.lines.Line2D at 0x2984f43ea00>,
#  <matplotlib.lines.Line2D at 0x2984f43eb20>,
#  <matplotlib.lines.Line2D at 0x2984f43ec40>,
#  <matplotlib.lines.Line2D at 0x2984f43ed60>,
#  <matplotlib.lines.Line2D at 0x2984f43ee80>,
#  <matplotlib.lines.Line2D at 0x2984f43efa0>,
#  <matplotlib.lines.Line2D at 0x2984f463100>,
#  <matplotlib.lines.Line2D at 0x2984f463220>,
#  <matplotlib.lines.Line2D at 0x2984f463340>,
#  <matplotlib.lines.Line2D at 0x2984f463460>,
#  <matplotlib.lines.Line2D at 0x2984f463580>,
#  <matplotlib.lines.Line2D at 0x2984f4636a0>,
#  <matplotlib.lines.Line2D at 0x2984f4637c0>,
#  <matplotlib.lines.Line2D at 0x2984f4638e0>,
#  <matplotlib.lines.Line2D at 0x2984f463a00>,
#  <matplotlib.lines.Line2D at 0x2984f463b20>,
#  <matplotlib.lines.Line2D at 0x2984f463c40>,
#  <matplotlib.lines.Line2D at 0x2984f463d60>,
#  <matplotlib.lines.Line2D at 0x2984f463e80>,
#  <matplotlib.lines.Line2D at 0x2984f463fa0>,
#  <matplotlib.lines.Line2D at 0x2984f439100>,
#  <matplotlib.lines.Line2D at 0x2984f439220>,
#  <matplotlib.lines.Line2D at 0x2984f439340>,
#  <matplotlib.lines.Line2D at 0x2984f439460>,
#  <matplotlib.lines.Line2D at 0x2984f439580>,
#  <matplotlib.lines.Line2D at 0x2984f4396a0>,
#  <matplotlib.lines.Line2D at 0x2984f4397c0>,
#  <matplotlib.lines.Line2D at 0x2984f4398e0>,
#  <matplotlib.lines.Line2D at 0x2984f439a00>,
#  <matplotlib.lines.Line2D at 0x2984f439b20>,
#  <matplotlib.lines.Line2D at 0x2984f439c40>,
#  <matplotlib.lines.Line2D at 0x2984f439d60>,
#  <matplotlib.lines.Line2D at 0x2984f439e80>,
#  <matplotlib.lines.Line2D at 0x2984f439fa0>,
#  <matplotlib.lines.Line2D at 0x2984f441100>,
#  <matplotlib.lines.Line2D at 0x2984f441220>,
#  <matplotlib.lines.Line2D at 0x2984f441340>,
#  <matplotlib.lines.Line2D at 0x2984f441460>,
#  <matplotlib.lines.Line2D at 0x2984f441580>,
#  <matplotlib.lines.Line2D at 0x2984f4416a0>,
#  <matplotlib.lines.Line2D at 0x2984f4417c0>,
#  <matplotlib.lines.Line2D at 0x2984f4418e0>,
#  <matplotlib.lines.Line2D at 0x2984f441a00>,
#  <matplotlib.lines.Line2D at 0x2984f441b20>,
#  <matplotlib.lines.Line2D at 0x2984f441c40>,
#  <matplotlib.lines.Line2D at 0x2984f441d60>,
#  <matplotlib.lines.Line2D at 0x2984f441e80>,
#  <matplotlib.lines.Line2D at 0x2984f441fa0>,
#  <matplotlib.lines.Line2D at 0x2984f469100>,
#  <matplotlib.lines.Line2D at 0x2984f469220>,
#  <matplotlib.lines.Line2D at 0x2984f469340>,
#  <matplotlib.lines.Line2D at 0x2984f469460>,
#  <matplotlib.lines.Line2D at 0x2984f469580>,
#  <matplotlib.lines.Line2D at 0x2984f4696a0>,
#  <matplotlib.lines.Line2D at 0x2984f4697c0>,
#  <matplotlib.lines.Line2D at 0x2984f4698e0>,
#  <matplotlib.lines.Line2D at 0x2984f469a00>,
#  <matplotlib.lines.Line2D at 0x2984f469b20>,
#  <matplotlib.lines.Line2D at 0x2984f469c40>,
#  <matplotlib.lines.Line2D at 0x2984f469d60>,
#  <matplotlib.lines.Line2D at 0x2984f469e80>,
#  <matplotlib.lines.Line2D at 0x2984f469fa0>,
#  <matplotlib.lines.Line2D at 0x2984f432100>,
#  <matplotlib.lines.Line2D at 0x2984f432220>,
#  <matplotlib.lines.Line2D at 0x2984f432340>,
#  <matplotlib.lines.Line2D at 0x2984f432460>,
#  <matplotlib.lines.Line2D at 0x2984f432580>,
#  <matplotlib.lines.Line2D at 0x2984f4326a0>,
#  <matplotlib.lines.Line2D at 0x2984f4327c0>,
#  <matplotlib.lines.Line2D at 0x2984f4328e0>,
#  <matplotlib.lines.Line2D at 0x2984f432a00>,
#  <matplotlib.lines.Line2D at 0x2984f432b20>,
#  <matplotlib.lines.Line2D at 0x2984f432c40>,
#  <matplotlib.lines.Line2D at 0x2984f432d60>,
#  <matplotlib.lines.Line2D at 0x2984f432e80>,
#  <matplotlib.lines.Line2D at 0x2984f432fa0>,
#  <matplotlib.lines.Line2D at 0x2984f44c100>,
#  <matplotlib.lines.Line2D at 0x2984f44c220>,
#  <matplotlib.lines.Line2D at 0x2984f44c340>,
#  <matplotlib.lines.Line2D at 0x2984f44c460>,
#  <matplotlib.lines.Line2D at 0x2984f44c580>,
#  <matplotlib.lines.Line2D at 0x2984f44c6a0>,
#  <matplotlib.lines.Line2D at 0x2984f44c7c0>,
#  <matplotlib.lines.Line2D at 0x2984f44c8e0>,
#  <matplotlib.lines.Line2D at 0x2984f44ca00>,
#  <matplotlib.lines.Line2D at 0x2984f44cb20>,
#  <matplotlib.lines.Line2D at 0x2984f44cc40>,
#  <matplotlib.lines.Line2D at 0x2984f44cd60>,
#  <matplotlib.lines.Line2D at 0x2984f44ce80>,
#  <matplotlib.lines.Line2D at 0x2984f44cfa0>,
#  <matplotlib.lines.Line2D at 0x2984f457100>,
#  <matplotlib.lines.Line2D at 0x2984f457220>,
#  <matplotlib.lines.Line2D at 0x2984f457340>,
#  <matplotlib.lines.Line2D at 0x2984f457460>,
#  <matplotlib.lines.Line2D at 0x2984f457580>,
#  <matplotlib.lines.Line2D at 0x2984f4576a0>,
#  <matplotlib.lines.Line2D at 0x2984f4577c0>,
#  <matplotlib.lines.Line2D at 0x2984f4578e0>,
#  <matplotlib.lines.Line2D at 0x2984f457a00>,
#  <matplotlib.lines.Line2D at 0x2984f457b20>,
#  <matplotlib.lines.Line2D at 0x2984f457c40>,
#  <matplotlib.lines.Line2D at 0x2984f457d60>,
#  <matplotlib.lines.Line2D at 0x2984f457e80>,
#  <matplotlib.lines.Line2D at 0x2984f457fa0>,
#  <matplotlib.lines.Line2D at 0x2984f44b100>,
#  <matplotlib.lines.Line2D at 0x2984f44b220>,
#  <matplotlib.lines.Line2D at 0x2984f44b340>,
#  <matplotlib.lines.Line2D at 0x2984f44b460>,
#  <matplotlib.lines.Line2D at 0x2984f44b580>,
#  <matplotlib.lines.Line2D at 0x2984f44b6a0>,
#  <matplotlib.lines.Line2D at 0x2984f44b7c0>,
#  <matplotlib.lines.Line2D at 0x2984f44b8e0>,
#  <matplotlib.lines.Line2D at 0x2984f44ba00>,
#  <matplotlib.lines.Line2D at 0x2984f44bb20>,
#  <matplotlib.lines.Line2D at 0x2984f44bc40>,
#  <matplotlib.lines.Line2D at 0x2984f44bd60>,
#  <matplotlib.lines.Line2D at 0x2984f44be80>,
#  <matplotlib.lines.Line2D at 0x2984f44bfa0>,
#  <matplotlib.lines.Line2D at 0x2984f4e5100>,
#  <matplotlib.lines.Line2D at 0x2984f4e5220>,
#  <matplotlib.lines.Line2D at 0x2984f4e5340>,
#  <matplotlib.lines.Line2D at 0x2984f4e5460>,
#  <matplotlib.lines.Line2D at 0x2984f4e5580>,
#  <matplotlib.lines.Line2D at 0x2984f4e56a0>,
#  <matplotlib.lines.Line2D at 0x2984f4e57c0>,
#  <matplotlib.lines.Line2D at 0x2984f4e58e0>,
#  <matplotlib.lines.Line2D at 0x2984f48a790>,
#  <matplotlib.lines.Line2D at 0x2984f48a7f0>,
#  <matplotlib.lines.Line2D at 0x2984f4e5b20>]

# %%
plt.plot(df.날짜,df['강원도 강릉시'])
plt.xlabel('Time',fontsize=20)
plt.ylabel('방문자 수',fontsize=20)
# Out:
# Text(0, 0.5, '방문자 수')

# %%
data_array = np.array(df.T.drop('날짜').values)
data_array
# Out:
# array([[197344.0, 87395.0, 92099.0, ..., 85176.0, 95431.0, 134372.0],
#        [57981.0, 25466.0, 25329.5, ..., 26351.5, 30772.0, 47218.5],
#        [55454.0, 24920.0, 28948.5, ..., 26173.0, 28717.5, 41352.5],
#        ...,
#        [61400.5, 52535.0, 60886.0, ..., 64134.0, 64806.0, 73353.0],
#        [79425.5, 70486.5, 81385.5, ..., 90156.5, 92939.0, 102445.0],
#        [55475.0, 37124.5, 42959.0, ..., 48429.5, 53133.5, 70637.0]],
#       dtype=object)

# %%
from tslearn.clustering import TimeSeriesKMeans
from yellowbrick.cluster import KElbowVisualizer

model = TimeSeriesKMeans(metric="softdtw")
visualizer = KElbowVisualizer(model, k=(1, 20))
visualizer.fit(data_array.reshape(-1, 1))

# %% [markdown]
# # ------------------------구분선---------------------------------

# %%
data_array.head()

# %%
#data_array = np.array(df.T.drop('날짜').values)
#from tslearn.clustering import TimeSeriesKMeans
model = TimeSeriesKMeans(n_clusters=3, metric="softdtw", max_iter=50, n_jobs=-1)
model.fit(data_array)
cities_list = df.T.drop('날짜').index.tolist()

# %%
y=model.predict(data_array)
# Out:
# C:\Anaconda3\lib\site-packages\tslearn\utils\utils.py:89: UserWarning: 2-Dimensional data passed. Assuming these are 9 1-dimensional timeseries
#   '{} 1-dimensional timeseries'.format(X.shape[0]))

# %%
x = undersample_data.날짜

# %%
plt.figure(figsize=(20,20))
k_dict = {'1':0,'2':0,'3':0,'4':1,'5':1,'6':1,'7':2,'8':2,'9':2}
colors = ['navy']*3+['darkorange']*3+['k']*3
Names = ['Class 0']*3+['Class 1']*3+['Class 2']*3

for j in range(1,10):
    plt.subplot(3,3,j)
    k = np.random.choice(np.where(y==k_dict[str(j)])[0])
    plt.plot(x,data_array[k],'-',color=colors[j-1])
    plt.ylabel('값',fontsize=20)
    plt.xlabel('Time',fontsize=20)
    plt.title('City=%s, Class = %s'%(cities_list[k],Names[j-1]),fontsize=20)
    plt.ylim(data_array.min(),data_array.max())

# %%
plt.figure(figsize=(20,20))
k_dict = {'1':0,'2':0,'3':0,'4':1,'5':1,'6':1,'7':2,'8':2,'9':2}
colors = ['navy']*3+['darkorange']*3+['k']*3
Names = ['Class 0']*3+['Class 1']*3+['Class 2']*3
for j in range(1,10):
    plt.subplot(3,3,j)
    k = np.random.choice(np.where(y==k_dict[str(j)])[0])
    plt.hist(data_array[k],color=colors[j-1])
    plt.ylabel('값',fontsize=20)
    plt.xlabel('Time',fontsize=20)
    plt.title('City=%s, Class = %s'%(cities_list[k],Names[j-1]),fontsize=20)
    plt.xlim(data_array.min(),data_array.max())

# %%
data_array = np.array(undersample_data.T.drop('기준연월').values)
from tslearn.clustering import TimeSeriesKMeans
model = TimeSeriesKMeans(n_clusters=3, metric="dtw", max_iter=10)
model.fit(data_array)
cities_list = undersample_data.T.drop('기준연월').index.tolist()

# %%
y=model.predict(data_array)
# Out:
# C:\Anaconda3\lib\site-packages\tslearn\utils\utils.py:89: UserWarning: 2-Dimensional data passed. Assuming these are 9 1-dimensional timeseries
#   '{} 1-dimensional timeseries'.format(X.shape[0]))

# %%
x = undersample_data.기준연월

# %%
plt.figure(figsize=(20,20))
k_dict = {'1':0,'2':0,'3':0,'4':1,'5':1,'6':1,'7':2,'8':2,'9':2}
colors = ['navy']*3+['darkorange']*3+['k']*3
Names = ['Class 0']*3+['Class 1']*3+['Class 2']*3

for j in range(1,10):
    plt.subplot(3,3,j)
    k = np.random.choice(np.where(y==k_dict[str(j)])[0])
    plt.plot(x,data_array[k],'.',color=colors[j-1])
    plt.ylabel('값',fontsize=20)
    plt.xlabel('Time',fontsize=20)
    plt.title('City=%s, Class = %s'%(cities_list[k],Names[j-1]),fontsize=20)
    plt.ylim(data_array.min(),data_array.max())

# %%
plt.figure(figsize=(20,20))
k_dict = {'1':0,'2':0,'3':0,'4':1,'5':1,'6':1,'7':2,'8':2,'9':2}
colors = ['navy']*3+['darkorange']*3+['k']*3
Names = ['Class 0']*3+['Class 1']*3+['Class 2']*3
for j in range(1,10):
    plt.subplot(3,3,j)
    k = np.random.choice(np.where(y==k_dict[str(j)])[0])
    plt.hist(data_array[k],color=colors[j-1])
    plt.ylabel('값',fontsize=20)
    plt.xlabel('Time',fontsize=20)
    plt.title('City=%s, Class = %s'%(cities_list[k],Names[j-1]),fontsize=20)
    plt.xlim(data_array.min(),data_array.max())

# %%
data_array = np.array(undersample_data.T.drop('기준연월').values)
from tslearn.clustering import TimeSeriesKMeans
model = TimeSeriesKMeans(n_clusters=3, metric="euclidean", max_iter=10)
model.fit(data_array)
cities_list = undersample_data.T.drop('기준연월').index.tolist()

# %%
y=model.predict(data_array)
# Out:
# C:\Anaconda3\lib\site-packages\tslearn\utils\utils.py:89: UserWarning: 2-Dimensional data passed. Assuming these are 9 1-dimensional timeseries
#   '{} 1-dimensional timeseries'.format(X.shape[0]))

# %%
x = undersample_data.기준연월

# %%
plt.figure(figsize=(20,20))
k_dict = {'1':0,'2':0,'3':0,'4':1,'5':1,'6':1,'7':2,'8':2,'9':2}
colors = ['navy']*3+['darkorange']*3+['k']*3
Names = ['Class 0']*3+['Class 1']*3+['Class 2']*3

for j in range(1,10):
    plt.subplot(3,3,j)
    k = np.random.choice(np.where(y==k_dict[str(j)])[0])
    plt.plot(x,data_array[k],'.',color=colors[j-1])
    plt.ylabel('값',fontsize=20)
    plt.xlabel('Time',fontsize=20)
    plt.title('City=%s, Class = %s'%(cities_list[k],Names[j-1]),fontsize=20)
    plt.ylim(data_array.min(),data_array.max())

# %%
plt.figure(figsize=(20,20))
k_dict = {'1':0,'2':0,'3':0,'4':1,'5':1,'6':1,'7':2,'8':2,'9':2}
colors = ['navy']*3+['darkorange']*3+['k']*3
Names = ['Class 0']*3+['Class 1']*3+['Class 2']*3
for j in range(1,10):
    plt.subplot(3,3,j)
    k = np.random.choice(np.where(y==k_dict[str(j)])[0])
    plt.hist(data_array[k],color=colors[j-1])
    plt.ylabel('값',fontsize=20)
    plt.xlabel('Time',fontsize=20)
    plt.title('City=%s, Class = %s'%(cities_list[k],Names[j-1]),fontsize=20)
    plt.xlim(data_array.min(),data_array.max())

# %%
import ipywidgets as widgets

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from ipywidgets import interact
import numpy as np

def f(k):
    x = np.linspace(0, 10, num=1000)
    y = np.sin(k*x)
    plt.plot(x, y)
    plt.show()

interact(f, k=(0.0,5.0,0.1) )

# %matplotlib inline
import matplotlib.pyplot as plt
from ipywidgets import interact
import numpy as np

x = np.linspace(0, 2*np.pi, num=5000)
y, y1, y2, y3 = [], [], [], []

param = 50

for i in range(1,param+1):
    y1.append([np.sin(i*j) for j in x])
    y2.append([np.cos(i*j)+np.cos(j) for j in x])
    y3.append([np.tan(i*j)+np.cos(j) for j in x])

y = [y1, y2, y3]

# 그래프를 생성
@interact(k=(0,param-1))
def f(k):
    # 3개의 그래프를 배치할 테두리를 만든다 
    fig,ax = plt.subplots(1,3,figsize=(17,4))

    # 타이틀을 배열에 저장한다
    title=['title1','title2','title3']

    # 그래프간의 간격을 조정한다
    plt.subplots_adjust(wspace=0.25, hspace=0.6)

    for i in range(3):
        ax[i].plot(x, y[i][k])
        ax[i].set_title(title[i]) # 타이틀
        ax[i].set_xlabel('x-axis label') # x축의 라벨
        ax[i].set_ylabel('y-axis label') # y축의 라벨

    plt.show()
# Out:
# interactive(children=(FloatSlider(value=2.5, description='k', max=5.0), Output()), _dom_classes=('widget-inter…
# interactive(children=(IntSlider(value=24, description='k', max=49), Output()), _dom_classes=('widget-interact'…
